# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('rent.csv')

# %%
df
# Out:
#        Posted On  BHK   Rent    Size            Floor    Area Type  \
# 0     2022-05-18  2.0  10000  1100.0  Ground out of 2   Super Area
# 1     2022-05-13  2.0  20000   800.0       1 out of 3   Super Area
# 2     2022-05-16  2.0  17000  1000.0       1 out of 3   Super Area
# 3     2022-07-04  NaN  10000   800.0       1 out of 2   Super Area
# 4     2022-05-09  2.0   7500   850.0       1 out of 2  Carpet Area
# ...          ...  ...    ...     ...              ...          ...
# 4741  2022-05-18  2.0  15000  1000.0       3 out of 5  Carpet Area
# 4742  2022-05-15  3.0  29000  2000.0       1 out of 4   Super Area
# 4743  2022-07-10  3.0  35000  1750.0       3 out of 5  Carpet Area
# 4744  2022-07-06  3.0  45000  1500.0     23 out of 34  Carpet Area
# 4745  2022-05-04  2.0  15000  1000.0       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4743 non-null   float64
#  2   Rent               4746 non-null   int64
#  3   Size               4741 non-null   float64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 445.1+ KB

# %%
sns.displot(df['BHK'])

# %%
sns.displot(df['Rent'])

# %%
df['Rent'].sort_values()
# Out:
# 4076       1200
# 285        1500
# 471        1800
# 2475       2000
# 146        2200
#          ...
# 1459     700000
# 1329     850000
# 827     1000000
# 1001    1200000
# 1837    3500000
# Name: Rent, Length: 4746, dtype: int64

# %%
sns.boxplot(y=df['Rent'])
# Out:
# <Axes: ylabel='Rent'>

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  3
# Rent                 0
# Size                 5
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
df.dropna(subset=['Size'])
# Out:
#        Posted On  BHK   Rent    Size            Floor    Area Type  \
# 0     2022-05-18  2.0  10000  1100.0  Ground out of 2   Super Area
# 1     2022-05-13  2.0  20000   800.0       1 out of 3   Super Area
# 2     2022-05-16  2.0  17000  1000.0       1 out of 3   Super Area
# 3     2022-07-04  NaN  10000   800.0       1 out of 2   Super Area
# 4     2022-05-09  2.0   7500   850.0       1 out of 2  Carpet Area
# ...          ...  ...    ...     ...              ...          ...
# 4741  2022-05-18  2.0  15000  1000.0       3 out of 5  Carpet Area
# 4742  2022-05-15  3.0  29000  2000.0       1 out of 4   Super Area
# 4743  2022-07-10  3.0  35000  1750.0       3 out of 5  Carpet Area
# 4744  2022-07-06  3.0  45000  1500.0     23 out of 34  Carpet Area
# 4745  2022-05-04  2.0  15000  1000.0       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df[df['Size'].isnull()]
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 425   2022-05-22  2.0   9000   NaN       2 out of 3   Super Area
# 430   2022-05-08  2.0   8500   NaN  Ground out of 1  Carpet Area
# 4703  2022-07-06  2.0  12000   NaN       4 out of 4   Super Area
# 4731  2022-06-24  2.0  13000   NaN       2 out of 2   Super Area
# 4732  2022-07-08  2.0   7000   NaN  Ground out of 2   Super Area
#
#                                 Area Locality       City Furnishing Status  \
# 425                       Airport Area Behala    Kolkata         Furnished
# 430                                   Nayabad    Kolkata       Unfurnished
# 4703  Anandbagh, Secunderabad, Moula Ali Road  Hyderabad         Furnished
# 4731               Manikonda, Outer Ring Road  Hyderabad       Unfurnished
# 4732                           Vinayaka Nagar  Hyderabad       Unfurnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 425   Bachelors/Family         2    Contact Owner
# ...

# %%
na_index = df[df['Size'].isnull()].index
na_index
# Out:
# Index([425, 430, 4703, 4731, 4732], dtype='int64')

# %%
sns.boxplot(y=df['Size'])
# Out:
# <Axes: ylabel='Size'>

# %%
na_index = df[df['Size'].isna()].index
na_index

df['Size'] = df['Size'].fillna(df['Size'].median())

# %%
na_index1 = df[df['BHK'].isnull()].index
na_index1

df['BHK'] = df['BHK'].fillna(df['BHK'].median())

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
df['Area Type'].unique()
# Out:
# array(['Super Area', 'Carpet Area', 'Built Area'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   float64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   float64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 445.1+ KB

# %%
df = df.drop(['Posted On', 'Floor', 'Area Locality', 'Tenant Preferred','Point of Contact'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BHK                4746 non-null   float64
#  1   Rent               4746 non-null   int64
#  2   Size               4746 non-null   float64
#  3   Area Type          4746 non-null   object
#  4   City               4746 non-null   object
#  5   Furnishing Status  4746 non-null   object
#  6   Bathroom           4746 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 259.7+ KB

# %%
df['Area Type'].unique()
# Out:
# array(['Super Area', 'Carpet Area', 'Built Area'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Kolkata', 'Mumbai', 'Bangalore', 'Delhi', 'Chennai', 'Hyderabad'],
#       dtype=object)

# %%
df['Furnishing Status'].unique()
# Out:
# array(['Unfurnished', 'Semi-Furnished', 'Furnished'], dtype=object)

# %%
df = pd.get_dummies(df, columns = ['Area Type', 'City', 'Furnishing Status'])
df
# Out:
#       BHK   Rent    Size  Bathroom  Area Type_Built Area  \
# 0     2.0  10000  1100.0         2                 False
# 1     2.0  20000   800.0         1                 False
# 2     2.0  17000  1000.0         1                 False
# 3     2.0  10000   800.0         1                 False
# 4     2.0   7500   850.0         1                 False
# ...   ...    ...     ...       ...                   ...
# 4741  2.0  15000  1000.0         2                 False
# 4742  3.0  29000  2000.0         3                 False
# 4743  3.0  35000  1750.0         3                 False
# 4744  3.0  45000  1500.0         2                 False
# 4745  2.0  15000  1000.0         2                 False
#
#       Area Type_Carpet Area  Area Type_Super Area  City_Bangalore  \
# 0                     False                  True           False
# 1                     False                  True           False
# 2                     False                  True           False
# ...

# %%
X = df.drop('Rent', axis=1)
y = df['Rent']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.2, random_state= 17)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(X_test)
pred
# Out:
# array([ -3054.14662171, 104044.52410117,   5254.62753467, ...,
#        114586.13514837,  16095.00160879, -23491.50062374])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mean_squared_error(y_test, pred)
# Out:
# 1866008505.9842737

# %%
mean_squared_error(y_test, pred, squared = False)
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 43197.320588021124

# %%
mean_absolute_error(y_test, pred)
# Out:
# 27532.88602215312
